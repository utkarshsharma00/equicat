# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, VarianceThreshold
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor
from time import time
import scipy.stats as stats
import re

# Set up display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Define base seed and number of runs
BASE_SEED = 107843579
NUM_RUNS = 3

# %%
# Function to load embeddings from JSON file and strip family prefix
def load_embeddings(file_path):
    with open(file_path, 'r') as f:
        raw_embeddings = json.load(f)
    
    embeddings = {}
    family_pattern = re.compile(r'^family\d+_')
    for key, value in raw_embeddings.items():
        stripped_key = family_pattern.sub('', key)
        embeddings[stripped_key] = np.array(value)
    
    return embeddings

# Function to create dataset
def create_dataset(embeddings, Y_df):
    X_data = []
    Y_data = []
    
    for _, row in Y_df.iterrows():
        catalyst_id = row['catalyst_id']
        imine_id = row['imine_id']
        thiol_id = row['thiol_id']
        product_id = row['product_id']
        
        if all(id in embeddings for id in [catalyst_id, imine_id, thiol_id, product_id]):
            combined_embedding = np.concatenate([
                embeddings[catalyst_id],
                embeddings[imine_id],
                embeddings[thiol_id],
                embeddings[product_id]
            ])
            X_data.append(combined_embedding)
            Y_data.append(row['selectivity_ddGact_kcal'])
    
    return np.array(X_data), np.array(Y_data)

# %%
def train_and_evaluate(X_data, Y_data, seed):
    X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.7, random_state=seed)
    
    f_select_model = RandomForestRegressor(n_estimators=1000, n_jobs=64, random_state=seed)
    
    pipe_random = Pipeline(steps=[
        ('preprocess', VarianceThreshold(1e-3)),
        ('feature_selection', SelectFromModel(f_select_model, max_features=30)),
        ('model', GradientBoostingRegressor(n_estimators=500, learning_rate=0.01))
    ])
    
    param_dict = {
        'model__learning_rate': np.logspace(-4, 0, 20),
        'model__subsample': np.linspace(0.5, 1.0, 10),
        'model__min_weight_fraction_leaf': (np.random.uniform(0.0, .5, 20)),
        'model__max_depth': [3,4,5,6,7,8,9,10,None],
        'model__max_features': (np.random.uniform(0.01, .99, 20)),
        'model__max_leaf_nodes': [10,100,1000,None],
        'model__n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
    }
    
    search = RandomizedSearchCV(pipe_random, cv=5, param_distributions=param_dict,
                              n_iter=100, n_jobs=64, verbose=3, refit='neg_mean_absolute_error',
                              scoring=['neg_mean_absolute_error', 'r2'])
    
    search.fit(X_train, Y_train)
    best_model = search.best_estimator_
    
    Y_pred_train = best_model.predict(X_train)
    Y_pred_test = best_model.predict(X_test)
    
    results = {
        'model': best_model,
        'train_data': (X_train, Y_train, Y_pred_train),
        'test_data': (X_test, Y_test, Y_pred_test),
        'metrics': {
            'train_r2': r2_score(Y_train, Y_pred_train),
            'test_r2': r2_score(Y_test, Y_pred_test),
            'train_mae': mean_absolute_error(Y_train, Y_pred_train),
            'test_mae': mean_absolute_error(Y_test, Y_pred_test)
        }
    }
    
    return results

# %%
def plot_aggregated_results(all_results, title, file_dpi=800):
    plt.figure(figsize=(10, 6))
    
    # Plot training data
    train_y_true = []
    train_y_pred = []
    for result in all_results:
        _, y_true, y_pred = result['train_data']
        train_y_true.extend(y_true)
        train_y_pred.extend(y_pred)
    
    # Plot test data
    test_y_true = []
    test_y_pred = []
    for result in all_results:
        _, y_true, y_pred = result['test_data']
        test_y_true.extend(y_true)
        test_y_pred.extend(y_pred)
    
    # Calculate average metrics
    train_r2_mean = np.mean([r['metrics']['train_r2'] for r in all_results])
    train_r2_std = np.std([r['metrics']['train_r2'] for r in all_results])
    test_r2_mean = np.mean([r['metrics']['test_r2'] for r in all_results])
    test_r2_std = np.std([r['metrics']['test_r2'] for r in all_results])
    
    train_mae_mean = np.mean([r['metrics']['train_mae'] for r in all_results])
    train_mae_std = np.std([r['metrics']['train_mae'] for r in all_results])
    test_mae_mean = np.mean([r['metrics']['test_mae'] for r in all_results])
    test_mae_std = np.std([r['metrics']['test_mae'] for r in all_results])
    
    plt.scatter(train_y_true, train_y_pred, color='gray', alpha=0.5,
               label=f'Train (R² = {train_r2_mean:.3f} ± {train_r2_std:.3f})')
    plt.scatter(test_y_true, test_y_pred, color='blue', alpha=0.5,
               label=f'Test (R² = {test_r2_mean:.3f} ± {test_r2_std:.3f})')
    
    plt.plot([-3, 3], [-3, 3], 'k--', alpha=0.5)
    plt.xlabel('Observed')
    plt.ylabel('Predicted')
    plt.title(title)
    plt.legend()
    plt.xlim(-3, 3)
    plt.ylim(-3, 3)
    
    plt.savefig(f"{title}_aggregated.png", dpi=file_dpi)
    plt.close()
    
    # Print aggregated metrics
    print("\nAggregated Results Summary:")
    print(f"Training R²: {train_r2_mean:.4f} ± {train_r2_std:.4f}")
    print(f"Test R²: {test_r2_mean:.4f} ± {test_r2_std:.4f}")
    print(f"Training MAE: {train_mae_mean:.4f} ± {train_mae_std:.4f} kcal/mol")
    print(f"Test MAE: {test_mae_mean:.4f} ± {test_mae_std:.4f} kcal/mol")

# %%
def main():
    # Load data
    try:
        embeddings = load_embeddings('/Users/utkarsh/MMLI/equicat/large/final_molecule_embeddings.json')
        Y_df = pd.read_csv('/Users/utkarsh/MMLI/equicat/science/Y_DATA.csv', dtype={
            'catalyst_id': str,
            'imine_id': str,
            'thiol_id': str,
            'product_id': str
        })
    except Exception as e:
        print(f"Error loading data: {str(e)}")
        return
    
    # Create dataset
    X_data, Y_data = create_dataset(embeddings, Y_df)
    
    # Perform multiple runs with different seeds
    all_results = []
    for i in range(NUM_RUNS):
        print(f"\nStarting Run {i+1}/{NUM_RUNS}")
        seed = BASE_SEED + i * 2  # Use a prime number offset
        np.random.seed(seed)
        results = train_and_evaluate(X_data, Y_data, seed)
        all_results.append(results)
    
    # Plot aggregated results
    plot_aggregated_results(all_results, "EQUICAT Prediction (Aggregated)")
    
    # Create ensemble predictor function
    def predict_ddg_ensemble(catalyst_id, imine_id, thiol_id, product_id):
        if all(id in embeddings for id in [catalyst_id, imine_id, thiol_id, product_id]):
            combined_embedding = np.concatenate([
                embeddings[catalyst_id],
                embeddings[imine_id],
                embeddings[thiol_id],
                embeddings[product_id]
            ])
            predictions = []
            for result in all_results:
                pred = result['model'].predict([combined_embedding])[0]
                predictions.append(pred)
            mean_pred = np.mean(predictions)
            std_pred = np.std(predictions)
            return mean_pred, std_pred
        else:
            return "One or more components not found in embeddings"
    
    # Example prediction
    example_row = Y_df.iloc[3]
    pred_mean, pred_std = predict_ddg_ensemble(
        example_row['catalyst_id'],
        example_row['imine_id'],
        example_row['thiol_id'],
        example_row['product_id']
    )
    print(f"\nPrediction for reaction {example_row['reaction_handle']}: "
          f"{pred_mean:.4f} ± {pred_std:.4f} kcal/mol")

if __name__ == "__main__":
    main()
# Out:
# Starting Run 1/3
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END model__learning_rate=0.0001623776739188721, model__max_depth=9, model__max_features=0.8187225210610961, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.21653137156334307, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.552) r2: (test=-0.015) total time=  58.9s
# [CV 2/5] END model__learning_rate=0.0001623776739188721, model__max_depth=9, model__max_features=0.8187225210610961, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.21653137156334307, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.564) r2: (test=0.021) total time= 1.4min
# [CV 1/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.023550864428603546, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.458) r2: (test=0.252) total time= 1.4min
# [CV 3/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.023550864428603546, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.485) r2: (test=0.227) total time= 1.5min
# [CV 3/5] END model__learning_rate=0.0001623776739188721, model__max_depth=9, model__max_features=0.8187225210610961, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.21653137156334307, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.564) r2: (test=0.004) total time= 1.5min
# [CV 2/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.023550864428603546, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.487) r2: (test=0.260) total time= 1.5min
# [CV 4/5] END model__learning_rate=0.0001623776739188721, model__max_depth=9, model__max_features=0.8187225210610961, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.21653137156334307, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.560) r2: (test=-0.134) total time= 1.5min
# [CV 5/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.023550864428603546, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.544) r2: (test=0.252) total time= 1.5min
# [CV 5/5] END model__learning_rate=0.0001623776739188721, model__max_depth=9, model__max_features=0.8187225210610961, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.21653137156334307, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.630) r2: (test=0.020) total time= 1.5min
# [CV 4/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.023550864428603546, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.465) r2: (test=0.190) total time= 1.5min
# [CV 2/5] END model__learning_rate=0.004832930238571752, model__max_depth=6, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=800, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.252) r2: (test=0.782) total time= 4.1min
# [CV 3/5] END model__learning_rate=0.004832930238571752, model__max_depth=6, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=800, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.311) r2: (test=0.644) total time= 4.2min
# [CV 4/5] END model__learning_rate=0.004832930238571752, model__max_depth=6, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=800, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.214) r2: (test=0.814) total time= 4.5min
# [CV 1/5] END model__learning_rate=0.004832930238571752, model__max_depth=6, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=800, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.236) r2: (test=0.771) total time= 4.5min
# [CV 5/5] END model__learning_rate=0.004832930238571752, model__max_depth=6, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=800, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.287) r2: (test=0.765) total time= 4.9min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.5325064776241945, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4256573193777273, model__n_estimators=700, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.483) r2: (test=0.245) total time= 5.0min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.5325064776241945, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4256573193777273, model__n_estimators=700, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.498) r2: (test=0.150) total time= 5.1min
# [CV 4/5] END model__learning_rate=0.007847599703514606, model__max_depth=10, model__max_features=0.24997785974353992, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.440) r2: (test=0.304) total time= 5.3min
# [CV 2/5] END model__learning_rate=0.002976351441631319, model__max_depth=6, model__max_features=0.05534050262819565, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=100, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.560) r2: (test=0.034) total time= 4.9min
# [CV 1/5] END model__learning_rate=0.00026366508987303583, model__max_depth=5, model__max_features=0.49844651805181844, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.512) r2: (test=0.110) total time= 5.5min
# [CV 1/5] END model__learning_rate=0.007847599703514606, model__max_depth=10, model__max_features=0.24997785974353992, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.437) r2: (test=0.336) total time= 5.0min
# [CV 5/5] END model__learning_rate=0.03359818286283781, model__max_depth=9, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.230) r2: (test=0.838) total time= 5.0min
# [CV 2/5] END model__learning_rate=0.03359818286283781, model__max_depth=9, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.186) r2: (test=0.878) total time= 5.0min
# [CV 5/5] END model__learning_rate=0.002976351441631319, model__max_depth=6, model__max_features=0.05534050262819565, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=100, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.627) r2: (test=0.031) total time= 4.5min
# [CV 1/5] END model__learning_rate=0.03359818286283781, model__max_depth=9, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.195) r2: (test=0.860) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.002976351441631319, model__max_depth=6, model__max_features=0.05534050262819565, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=100, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.563) r2: (test=0.009) total time= 5.0min
# [CV 4/5] END model__learning_rate=0.002976351441631319, model__max_depth=6, model__max_features=0.05534050262819565, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=100, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.555) r2: (test=-0.110) total time= 5.0min
# [CV 1/5] END model__learning_rate=0.002976351441631319, model__max_depth=6, model__max_features=0.05534050262819565, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=100, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.548) r2: (test=-0.004) total time= 5.0min
# [CV 4/5] END model__learning_rate=0.03359818286283781, model__max_depth=9, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.181) r2: (test=0.871) total time= 5.1min
# [CV 5/5] END model__learning_rate=0.007847599703514606, model__max_depth=10, model__max_features=0.24997785974353992, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.462) r2: (test=0.428) total time= 5.0min
# [CV 4/5] END model__learning_rate=0.012742749857031334, model__max_depth=3, model__max_features=0.05534050262819565, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.466) r2: (test=0.208) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.012742749857031334, model__max_depth=3, model__max_features=0.05534050262819565, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.474) r2: (test=0.235) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.007847599703514606, model__max_depth=10, model__max_features=0.24997785974353992, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.436) r2: (test=0.345) total time= 5.1min
# [CV 2/5] END model__learning_rate=0.012742749857031334, model__max_depth=3, model__max_features=0.05534050262819565, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.467) r2: (test=0.307) total time= 5.1min
# [CV 2/5] END model__learning_rate=0.007847599703514606, model__max_depth=10, model__max_features=0.24997785974353992, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.414) r2: (test=0.418) total time= 5.1min
# [CV 2/5] END model__learning_rate=0.0011288378916846883, model__max_depth=5, model__max_features=0.023550864428603546, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=500, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.508) r2: (test=0.201) total time= 4.8min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.5325064776241945, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4256573193777273, model__n_estimators=700, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.474) r2: (test=0.221) total time= 5.3min
# [CV 2/5] END model__learning_rate=0.03359818286283781, model__max_depth=7, model__max_features=0.023550864428603546, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.216) r2: (test=0.843) total time= 4.5min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=8, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.485) r2: (test=0.180) total time= 5.1min
# [CV 3/5] END model__learning_rate=0.03359818286283781, model__max_depth=9, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.171578384001023, model__n_estimators=300, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.291) r2: (test=0.706) total time= 5.1min
# [CV 5/5] END model__learning_rate=0.012742749857031334, model__max_depth=3, model__max_features=0.05534050262819565, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.508) r2: (test=0.337) total time= 5.1min
# [CV 5/5] END model__learning_rate=0.00026366508987303583, model__max_depth=5, model__max_features=0.49844651805181844, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.586) r2: (test=0.141) total time= 5.4min
# [CV 4/5] END model__learning_rate=0.0011288378916846883, model__max_depth=5, model__max_features=0.023550864428603546, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=500, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.494) r2: (test=0.103) total time= 4.6min
# [CV 5/5] END model__learning_rate=0.03359818286283781, model__max_depth=7, model__max_features=0.023550864428603546, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.248) r2: (test=0.809) total time= 5.1min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=3, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=400, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.424) r2: (test=0.425) total time= 5.1min
# [CV 1/5] END model__learning_rate=0.0001623776739188721, model__max_depth=8, model__max_features=0.11422317008998221, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15427804638997755, model__n_estimators=500, model__subsample=0.5; neg_mean_absolute_error: (test=-0.543) r2: (test=0.014) total time= 4.7min
# [CV 1/5] END model__learning_rate=0.05455594781168514, model__max_depth=3, model__max_features=0.6834639500166277, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3991474049180133, model__n_estimators=600, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.291) r2: (test=0.712) total time= 5.2min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=8, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.491) r2: (test=0.142) total time= 5.0min
# [CV 5/5] END model__learning_rate=0.0011288378916846883, model__max_depth=5, model__max_features=0.023550864428603546, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=500, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.568) r2: (test=0.192) total time= 4.4min
# [CV 1/5] END model__learning_rate=0.012742749857031334, model__max_depth=3, model__max_features=0.05534050262819565, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=400, model__subsample=0.5; neg_mean_absolute_error: (test=-0.468) r2: (test=0.230) total time= 4.5min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=8, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.476) r2: (test=0.216) total time= 5.1min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=3, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=400, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.402) r2: (test=0.378) total time= 5.1min
# [CV 3/5] END model__learning_rate=0.0011288378916846883, model__max_depth=5, model__max_features=0.023550864428603546, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=500, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.506) r2: (test=0.167) total time= 4.9min
# [CV 3/5] END model__learning_rate=0.05455594781168514, model__max_depth=3, model__max_features=0.6834639500166277, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3991474049180133, model__n_estimators=600, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.323) r2: (test=0.640) total time= 5.3min
# [CV 3/5] END model__learning_rate=0.0001623776739188721, model__max_depth=8, model__max_features=0.11422317008998221, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15427804638997755, model__n_estimators=500, model__subsample=0.5; neg_mean_absolute_error: (test=-0.557) r2: (test=0.026) total time= 5.0min
# [CV 4/5] END model__learning_rate=0.00026366508987303583, model__max_depth=5, model__max_features=0.49844651805181844, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.512) r2: (test=0.029) total time= 5.4min
# [CV 4/5] END model__learning_rate=0.05455594781168514, model__max_depth=3, model__max_features=0.6834639500166277, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3991474049180133, model__n_estimators=600, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.281) r2: (test=0.682) total time= 5.4min
# [CV 2/5] END model__learning_rate=0.0001623776739188721, model__max_depth=8, model__max_features=0.11422317008998221, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15427804638997755, model__n_estimators=500, model__subsample=0.5; neg_mean_absolute_error: (test=-0.557) r2: (test=0.046) total time= 4.8min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=8, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.466) r2: (test=0.269) total time= 5.3min
# [CV 1/5] END model__learning_rate=0.0011288378916846883, model__max_depth=5, model__max_features=0.023550864428603546, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=500, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.488) r2: (test=0.174) total time= 4.9min
# [CV 2/5] END model__learning_rate=0.05455594781168514, model__max_depth=3, model__max_features=0.6834639500166277, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3991474049180133, model__n_estimators=600, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.277) r2: (test=0.750) total time= 5.5min
# [CV 5/5] END model__learning_rate=0.05455594781168514, model__max_depth=3, model__max_features=0.6834639500166277, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3991474049180133, model__n_estimators=600, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.279) r2: (test=0.780) total time= 5.6min
# [CV 4/5] END model__learning_rate=0.0001623776739188721, model__max_depth=8, model__max_features=0.11422317008998221, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15427804638997755, model__n_estimators=500, model__subsample=0.5; neg_mean_absolute_error: (test=-0.550) r2: (test=-0.099) total time= 5.2min
# [CV 5/5] END model__learning_rate=0.0001623776739188721, model__max_depth=8, model__max_features=0.11422317008998221, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.15427804638997755, model__n_estimators=500, model__subsample=0.5; neg_mean_absolute_error: (test=-0.622) r2: (test=0.043) total time= 5.2min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.5325064776241945, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4256573193777273, model__n_estimators=700, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.509) r2: (test=0.102) total time= 5.8min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.5325064776241945, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.4256573193777273, model__n_estimators=700, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.541) r2: (test=0.239) total time= 6.2min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=3, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=400, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.409) r2: (test=0.384) total time= 6.0min
# [CV 2/5] END model__learning_rate=0.00026366508987303583, model__max_depth=5, model__max_features=0.49844651805181844, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.522) r2: (test=0.150) total time= 6.7min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=3, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=400, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.480) r2: (test=0.407) total time= 6.0min
# [CV 3/5] END model__learning_rate=0.03359818286283781, model__max_depth=7, model__max_features=0.023550864428603546, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.301) r2: (test=0.694) total time= 6.5min
# [CV 4/5] END model__learning_rate=0.03359818286283781, model__max_depth=7, model__max_features=0.023550864428603546, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.204) r2: (test=0.836) total time= 6.9min
# [CV 1/5] END model__learning_rate=0.03359818286283781, model__max_depth=7, model__max_features=0.023550864428603546, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.228) r2: (test=0.828) total time= 6.7min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=3, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=400, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.435) r2: (test=0.351) total time= 7.4min
# [CV 3/5] END model__learning_rate=0.00026366508987303583, model__max_depth=5, model__max_features=0.49844651805181844, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.1292389663626628, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.522) r2: (test=0.121) total time= 8.0min
# [CV 1/5] END model__learning_rate=0.615848211066026, model__max_depth=5, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=500, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.227) r2: (test=0.853) total time= 6.6min
# [CV 2/5] END model__learning_rate=0.615848211066026, model__max_depth=5, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=500, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.217) r2: (test=0.808) total time= 6.4min
# [CV 1/5] END model__learning_rate=0.007847599703514606, model__max_depth=9, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.491) r2: (test=0.165) total time= 5.8min
# [CV 4/5] END model__learning_rate=0.007847599703514606, model__max_depth=9, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.503) r2: (test=0.123) total time= 4.7min
# [CV 3/5] END model__learning_rate=0.615848211066026, model__max_depth=5, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=500, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.324) r2: (test=0.679) total time= 6.4min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=8, model__max_features=0.14007317018030324, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.400150462049367, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.528) r2: (test=0.280) total time= 6.8min
# [CV 3/5] END model__learning_rate=0.007847599703514606, model__max_depth=9, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.473) r2: (test=0.235) total time= 4.8min
# [CV 2/5] END model__learning_rate=0.007847599703514606, model__max_depth=9, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.485) r2: (test=0.242) total time= 4.8min
# [CV 3/5] END model__learning_rate=0.002976351441631319, model__max_depth=4, model__max_features=0.49844651805181844, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.511) r2: (test=0.125) total time= 4.5min
# [CV 4/5] END model__learning_rate=0.002976351441631319, model__max_depth=4, model__max_features=0.49844651805181844, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.540) r2: (test=-0.013) total time= 4.6min
# [CV 2/5] END model__learning_rate=0.002976351441631319, model__max_depth=4, model__max_features=0.49844651805181844, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.534) r2: (test=0.125) total time= 4.6min
# [CV 1/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.11422317008998221, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=500, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.192) r2: (test=0.882) total time= 4.8min
# [CV 5/5] END model__learning_rate=0.007847599703514606, model__max_depth=9, model__max_features=0.6403461011651842, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.525) r2: (test=0.272) total time= 4.8min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.4682062490535293, model__n_estimators=100, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.619) r2: (test=0.046) total time= 4.2min
# [CV 4/5] END model__learning_rate=0.615848211066026, model__max_depth=5, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=500, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.159) r2: (test=0.892) total time= 6.1min
# [CV 1/5] END model__learning_rate=0.002976351441631319, model__max_depth=4, model__max_features=0.49844651805181844, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.525) r2: (test=0.075) total time= 4.6min
# [CV 4/5] END model__learning_rate=0.615848211066026, model__max_depth=9, model__max_features=0.5283579639486308, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=400, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.184) r2: (test=0.865) total time= 4.8min
# [CV 5/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.11422317008998221, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=500, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.241) r2: (test=0.834) total time= 4.8min
# [CV 5/5] END model__learning_rate=0.002976351441631319, model__max_depth=4, model__max_features=0.49844651805181844, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.421095893547925, model__n_estimators=200, model__subsample=1.0; neg_mean_absolute_error: (test=-0.588) r2: (test=0.127) total time= 4.6min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.4682062490535293, model__n_estimators=100, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.547) r2: (test=0.004) total time= 4.4min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.4682062490535293, model__n_estimators=100, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.561) r2: (test=0.048) total time= 4.4min
# [CV 2/5] END model__learning_rate=0.615848211066026, model__max_depth=9, model__max_features=0.5283579639486308, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=400, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.174) r2: (test=0.887) total time= 4.9min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.4682062490535293, model__n_estimators=100, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.559) r2: (test=-0.106) total time= 4.3min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.4682062490535293, model__n_estimators=100, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.551) r2: (test=0.035) total time= 4.4min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=600, model__subsample=0.5; neg_mean_absolute_error: (test=-0.505) r2: (test=0.190) total time= 4.8min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=600, model__subsample=0.5; neg_mean_absolute_error: (test=-0.506) r2: (test=0.127) total time= 4.9min
# [CV 3/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.11422317008998221, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=500, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.226) r2: (test=0.832) total time= 4.9min
# [CV 5/5] END model__learning_rate=0.615848211066026, model__max_depth=5, model__max_features=0.8187225210610961, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=500, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.271) r2: (test=0.801) total time= 6.1min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=600, model__subsample=0.5; neg_mean_absolute_error: (test=-0.566) r2: (test=0.189) total time= 4.8min
# [CV 5/5] END model__learning_rate=0.615848211066026, model__max_depth=9, model__max_features=0.5283579639486308, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=400, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.227) r2: (test=0.847) total time= 4.9min
# [CV 2/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.11422317008998221, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=500, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.172) r2: (test=0.893) total time= 4.9min
# [CV 1/5] END model__learning_rate=1.0, model__max_depth=10, model__max_features=0.3453856925064916, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3808009707359266, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.222) r2: (test=0.849) total time= 4.8min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=600, model__subsample=0.5; neg_mean_absolute_error: (test=-0.500) r2: (test=0.158) total time= 4.9min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.4301462522031996, model__n_estimators=600, model__subsample=0.5; neg_mean_absolute_error: (test=-0.515) r2: (test=0.059) total time= 4.9min
# [CV 1/5] END model__learning_rate=0.615848211066026, model__max_depth=9, model__max_features=0.5283579639486308, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=400, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.225) r2: (test=0.844) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.615848211066026, model__max_depth=9, model__max_features=0.5283579639486308, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=400, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.251) r2: (test=0.780) total time= 5.0min
# [CV 5/5] END model__learning_rate=1.0, model__max_depth=10, model__max_features=0.3453856925064916, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3808009707359266, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.221) r2: (test=0.853) total time= 4.8min
# [CV 4/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.11422317008998221, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.15207030662461735, model__n_estimators=500, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.226) r2: (test=0.808) total time= 5.0min
# [CV 4/5] END model__learning_rate=1.0, model__max_depth=10, model__max_features=0.3453856925064916, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3808009707359266, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.192) r2: (test=0.859) total time= 4.9min
# [CV 2/5] END model__learning_rate=1.0, model__max_depth=10, model__max_features=0.3453856925064916, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3808009707359266, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.182) r2: (test=0.880) total time= 5.0min
# [CV 3/5] END model__learning_rate=1.0, model__max_depth=10, model__max_features=0.3453856925064916, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3808009707359266, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.245) r2: (test=0.788) total time= 5.0min
# [CV 1/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.8187225210610961, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3112319258321384, model__n_estimators=600, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.233) r2: (test=0.816) total time= 5.3min
# [CV 4/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.8187225210610961, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3112319258321384, model__n_estimators=600, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.198) r2: (test=0.855) total time= 5.6min
# [CV 3/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.035586840467226995, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=900, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.458) r2: (test=0.295) total time= 5.4min
# [CV 2/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.035586840467226995, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=900, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.433) r2: (test=0.384) total time= 5.6min
# [CV 4/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.035586840467226995, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=900, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.412) r2: (test=0.337) total time= 6.1min
# [CV 1/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.035586840467226995, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=900, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.420) r2: (test=0.355) total time= 6.4min
# [CV 5/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.8187225210610961, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3112319258321384, model__n_estimators=600, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.247) r2: (test=0.816) total time= 6.6min
# [CV 2/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.8187225210610961, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3112319258321384, model__n_estimators=600, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.211) r2: (test=0.843) total time= 7.4min
# [CV 3/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.8187225210610961, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3112319258321384, model__n_estimators=600, model__subsample=0.7222222222222222; neg_mean_absolute_error: (test=-0.298) r2: (test=0.698) total time= 7.5min
# [CV 5/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.035586840467226995, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.3555923201784238, model__n_estimators=900, model__subsample=0.5555555555555556; neg_mean_absolute_error: (test=-0.485) r2: (test=0.383) total time= 7.3min
# [CV 1/5] END model__learning_rate=0.03359818286283781, model__max_depth=None, model__max_features=0.6959226487556084, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.23812845656115333, model__n_estimators=1000, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.193) r2: (test=0.883) total time= 7.8min
# [CV 1/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.7475853776556054, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=800, model__subsample=0.5; neg_mean_absolute_error: (test=-0.202) r2: (test=0.869) total time= 7.1min
# [CV 3/5] END model__learning_rate=0.03359818286283781, model__max_depth=None, model__max_features=0.6959226487556084, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.23812845656115333, model__n_estimators=1000, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.260) r2: (test=0.774) total time= 7.7min
# [CV 4/5] END model__learning_rate=0.03359818286283781, model__max_depth=None, model__max_features=0.6959226487556084, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.23812845656115333, model__n_estimators=1000, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.163) r2: (test=0.898) total time= 7.7min
# [CV 2/5] END model__learning_rate=0.03359818286283781, model__max_depth=None, model__max_features=0.6959226487556084, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.23812845656115333, model__n_estimators=1000, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.162) r2: (test=0.903) total time= 7.8min
# [CV 3/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.7475853776556054, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=800, model__subsample=0.5; neg_mean_absolute_error: (test=-0.257) r2: (test=0.767) total time= 6.7min
# [CV 5/5] END model__learning_rate=0.03359818286283781, model__max_depth=None, model__max_features=0.6959226487556084, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.23812845656115333, model__n_estimators=1000, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.231) r2: (test=0.857) total time= 7.5min
# [CV 2/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.7475853776556054, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=800, model__subsample=0.5; neg_mean_absolute_error: (test=-0.161) r2: (test=0.905) total time= 7.0min
# [CV 1/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.03798767830663453, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=100, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.229) r2: (test=0.860) total time= 4.0min
# [CV 3/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.03798767830663453, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=100, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.279) r2: (test=0.741) total time= 4.0min
# [CV 4/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.7475853776556054, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=800, model__subsample=0.5; neg_mean_absolute_error: (test=-0.162) r2: (test=0.898) total time= 6.5min
# [CV 2/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.03798767830663453, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=100, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.218) r2: (test=0.840) total time= 4.1min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=300, model__subsample=1.0; neg_mean_absolute_error: (test=-0.453) r2: (test=0.333) total time= 4.2min
# [CV 5/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.03798767830663453, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=100, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.269) r2: (test=0.814) total time= 4.1min
# [CV 4/5] END model__learning_rate=0.615848211066026, model__max_depth=6, model__max_features=0.03798767830663453, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.15522889425133074, model__n_estimators=100, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.192) r2: (test=0.857) total time= 4.1min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=300, model__subsample=1.0; neg_mean_absolute_error: (test=-0.464) r2: (test=0.276) total time= 4.3min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=300, model__subsample=1.0; neg_mean_absolute_error: (test=-0.443) r2: (test=0.295) total time= 4.3min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=300, model__subsample=1.0; neg_mean_absolute_error: (test=-0.438) r2: (test=0.262) total time= 4.4min
# [CV 5/5] END model__learning_rate=0.03359818286283781, model__max_depth=3, model__max_features=0.7475853776556054, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.23712784549159177, model__n_estimators=800, model__subsample=0.5; neg_mean_absolute_error: (test=-0.228) r2: (test=0.857) total time= 6.6min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.17761728966598536, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.12310002470095038, model__n_estimators=300, model__subsample=1.0; neg_mean_absolute_error: (test=-0.514) r2: (test=0.323) total time= 4.5min
# [CV 5/5] END model__learning_rate=0.0006951927961775605, model__max_depth=6, model__max_features=0.24997785974353992, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.2681093775452259, model__n_estimators=500, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.590) r2: (test=0.130) total time= 4.5min
# ...
# [CV 3/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.47320668204577376, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.530) r2: (test=0.157) total time= 4.9min
# [CV 1/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.47320668204577376, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.440) r2: (test=0.243) total time= 5.0min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.4818534568636702, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.580) r2: (test=0.148) total time= 5.3min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=4, model__max_features=0.4818534568636702, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=900, model__subsample=1.0; neg_mean_absolute_error: (test=-0.498) r2: (test=0.203) total time= 5.4min
# [CV 2/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.47320668204577376, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.514) r2: (test=0.203) total time= 5.0min
# [CV 5/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.1845137346066788, model__n_estimators=300, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.319) r2: (test=0.563) total time= 4.3min
# [CV 1/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.25411703961199644, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.24827162170308753, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.469) r2: (test=0.135) total time= 4.4min
# [CV 3/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.1845137346066788, model__n_estimators=300, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.411) r2: (test=0.456) total time= 4.4min
# [CV 1/5] END model__learning_rate=0.3792690190732246, model__max_depth=10, model__max_features=0.059392386590491175, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.427706144968032, model__n_estimators=200, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.316) r2: (test=0.568) total time= 3.4min
# [CV 4/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.1845137346066788, model__n_estimators=300, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.499) r2: (test=0.363) total time= 4.4min
# [CV 2/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.1845137346066788, model__n_estimators=300, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.391) r2: (test=0.496) total time= 4.5min
# [CV 5/5] END model__learning_rate=0.00042813323987193956, model__max_depth=4, model__max_features=0.059392386590491175, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.14096674477679655, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.480) r2: (test=0.096) total time= 4.8min
# [CV 2/5] END model__learning_rate=0.00042813323987193956, model__max_depth=4, model__max_features=0.059392386590491175, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.14096674477679655, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.548) r2: (test=0.077) total time= 4.9min
# [CV 3/5] END model__learning_rate=0.00042813323987193956, model__max_depth=4, model__max_features=0.059392386590491175, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.14096674477679655, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.570) r2: (test=0.057) total time= 4.8min
# [CV 4/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.25411703961199644, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.24827162170308753, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.598) r2: (test=0.097) total time= 4.2min
# [CV 2/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.25411703961199644, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.24827162170308753, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.528) r2: (test=0.137) total time= 4.4min
# [CV 5/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.25411703961199644, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.24827162170308753, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.457) r2: (test=0.157) total time= 4.0min
# [CV 2/5] END model__learning_rate=0.3792690190732246, model__max_depth=10, model__max_features=0.059392386590491175, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.427706144968032, model__n_estimators=200, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.380) r2: (test=0.550) total time= 3.4min
# [CV 3/5] END model__learning_rate=0.05455594781168514, model__max_depth=9, model__max_features=0.49754450313963, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.174729505553174, model__n_estimators=200, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.187) r2: (test=0.882) total time= 3.7min
# [CV 1/5] END model__learning_rate=0.05455594781168514, model__max_depth=9, model__max_features=0.49754450313963, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.174729505553174, model__n_estimators=200, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.258) r2: (test=0.705) total time= 4.0min
# [CV 5/5] END model__learning_rate=0.05455594781168514, model__max_depth=9, model__max_features=0.49754450313963, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.174729505553174, model__n_estimators=200, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.140) r2: (test=0.916) total time= 3.5min
# [CV 4/5] END model__learning_rate=0.00042813323987193956, model__max_depth=4, model__max_features=0.059392386590491175, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.14096674477679655, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.613) r2: (test=0.057) total time= 4.9min
# [CV 3/5] END model__learning_rate=0.0018329807108324356, model__max_depth=6, model__max_features=0.25411703961199644, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.24827162170308753, model__n_estimators=200, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.555) r2: (test=0.096) total time= 4.4min
# [CV 1/5] END model__learning_rate=0.00042813323987193956, model__max_depth=4, model__max_features=0.059392386590491175, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.14096674477679655, model__n_estimators=500, model__subsample=0.8888888888888888; neg_mean_absolute_error: (test=-0.485) r2: (test=0.075) total time= 5.0min
# [CV 2/5] END model__learning_rate=0.05455594781168514, model__max_depth=9, model__max_features=0.49754450313963, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.174729505553174, model__n_estimators=200, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.173) r2: (test=0.880) total time= 3.8min
# [CV 5/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.47320668204577376, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.441) r2: (test=0.233) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.3792690190732246, model__max_depth=10, model__max_features=0.059392386590491175, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.427706144968032, model__n_estimators=200, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.342) r2: (test=0.676) total time= 3.3min
# [CV 4/5] END model__learning_rate=0.002976351441631319, model__max_depth=8, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.47320668204577376, model__n_estimators=700, model__subsample=0.6666666666666666; neg_mean_absolute_error: (test=-0.567) r2: (test=0.149) total time= 5.1min
# [CV 1/5] END model__learning_rate=0.004832930238571752, model__max_depth=10, model__max_features=0.22650644528897512, model__max_leaf_nodes=10, model__min_weight_fraction_leaf=0.1845137346066788, model__n_estimators=300, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.371) r2: (test=0.480) total time= 4.8min
# [CV 4/5] END model__learning_rate=0.05455594781168514, model__max_depth=9, model__max_features=0.49754450313963, model__max_leaf_nodes=None, model__min_weight_fraction_leaf=0.174729505553174, model__n_estimators=200, model__subsample=0.7777777777777778; neg_mean_absolute_error: (test=-0.336) r2: (test=0.716) total time= 3.8min
# [CV 4/5] END model__learning_rate=0.3792690190732246, model__max_depth=10, model__max_features=0.059392386590491175, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.427706144968032, model__n_estimators=200, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.440) r2: (test=0.535) total time= 3.3min
# [CV 5/5] END model__learning_rate=0.3792690190732246, model__max_depth=10, model__max_features=0.059392386590491175, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.427706144968032, model__n_estimators=200, model__subsample=0.9444444444444444; neg_mean_absolute_error: (test=-0.330) r2: (test=0.638) total time= 2.9min
# [CV 1/5] END model__learning_rate=0.007847599703514606, model__max_depth=4, model__max_features=0.5497460223997195, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.11707284319575134, model__n_estimators=800, model__subsample=1.0; neg_mean_absolute_error: (test=-0.266) r2: (test=0.699) total time= 5.0min
# [CV 5/5] END model__learning_rate=0.007847599703514606, model__max_depth=4, model__max_features=0.5497460223997195, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.11707284319575134, model__n_estimators=800, model__subsample=1.0; neg_mean_absolute_error: (test=-0.154) r2: (test=0.900) total time= 5.0min
# [CV 2/5] END model__learning_rate=0.007847599703514606, model__max_depth=4, model__max_features=0.5497460223997195, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.11707284319575134, model__n_estimators=800, model__subsample=1.0; neg_mean_absolute_error: (test=-0.167) r2: (test=0.887) total time= 5.0min
# [CV 4/5] END model__learning_rate=0.007847599703514606, model__max_depth=4, model__max_features=0.5497460223997195, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.11707284319575134, model__n_estimators=800, model__subsample=1.0; neg_mean_absolute_error: (test=-0.334) r2: (test=0.720) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.007847599703514606, model__max_depth=4, model__max_features=0.5497460223997195, model__max_leaf_nodes=100, model__min_weight_fraction_leaf=0.11707284319575134, model__n_estimators=800, model__subsample=1.0; neg_mean_absolute_error: (test=-0.221) r2: (test=0.846) total time= 5.0min
# [CV 3/5] END model__learning_rate=0.0006951927961775605, model__max_depth=8, model__max_features=0.7968936985761166, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=500, model__subsample=1.0; neg_mean_absolute_error: (test=-0.568) r2: (test=0.039) total time= 2.1min
# [CV 1/5] END model__learning_rate=0.0006951927961775605, model__max_depth=8, model__max_features=0.7968936985761166, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=500, model__subsample=1.0; neg_mean_absolute_error: (test=-0.484) r2: (test=0.079) total time= 2.4min
# [CV 4/5] END model__learning_rate=0.0006951927961775605, model__max_depth=8, model__max_features=0.7968936985761166, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=500, model__subsample=1.0; neg_mean_absolute_error: (test=-0.614) r2: (test=0.048) total time= 2.0min
# [CV 2/5] END model__learning_rate=0.0006951927961775605, model__max_depth=8, model__max_features=0.7968936985761166, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=500, model__subsample=1.0; neg_mean_absolute_error: (test=-0.547) r2: (test=0.072) total time= 2.2min
# [CV 5/5] END model__learning_rate=0.0006951927961775605, model__max_depth=8, model__max_features=0.7968936985761166, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.3948513209749255, model__n_estimators=500, model__subsample=1.0; neg_mean_absolute_error: (test=-0.472) r2: (test=0.097) total time= 1.7min
# [CV 5/5] END model__learning_rate=0.08858667904100823, model__max_depth=9, model__max_features=0.7669529785662264, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.04939423942700605, model__n_estimators=1000, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.197) r2: (test=0.809) total time= 2.4min
# [CV 3/5] END model__learning_rate=0.08858667904100823, model__max_depth=9, model__max_features=0.7669529785662264, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.04939423942700605, model__n_estimators=1000, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.214) r2: (test=0.856) total time= 2.5min
# [CV 1/5] END model__learning_rate=0.08858667904100823, model__max_depth=9, model__max_features=0.7669529785662264, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.04939423942700605, model__n_estimators=1000, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.269) r2: (test=0.679) total time= 2.8min
# [CV 2/5] END model__learning_rate=0.08858667904100823, model__max_depth=9, model__max_features=0.7669529785662264, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.04939423942700605, model__n_estimators=1000, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.181) r2: (test=0.882) total time= 2.5min
# [CV 4/5] END model__learning_rate=0.08858667904100823, model__max_depth=9, model__max_features=0.7669529785662264, model__max_leaf_nodes=1000, model__min_weight_fraction_leaf=0.04939423942700605, model__n_estimators=1000, model__subsample=0.6111111111111112; neg_mean_absolute_error: (test=-0.308) r2: (test=0.732) total time= 2.4min
#
# Aggregated Results Summary:
# Training R²: 0.8858 ± 0.1170
# Test R²: 0.7834 ± 0.1097
# Training MAE: 0.1625 ± 0.1012 kcal/mol
# Test MAE: 0.2407 ± 0.0769 kcal/mol
#
# Prediction for reaction 1_i_1_D: 1.1092 ± 0.1777 kcal/mol
